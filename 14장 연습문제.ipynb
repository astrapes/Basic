# %% [markdown]
# # 13장 연습문제

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
mpl.rc('font',family = 'Malgun Gothic')
mpl.rcParams['axes.unicode_minus'] = False   
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.rcParams["figure.figsize"] = (15,5)
plt.rcParams["font.size"] = 15
# %matplotlib inline

# %%
df = pd.read_csv('high_school_2019.csv',skiprows=[0],
                 names = ['지역','학교명','1학년 학급수','1학년 학생 수','2학년 학급수',
                          '2학년 학생 수','3학년 학급수','3학년 학생 수'])
df
# Out:
#                 지역                 학교명  1학년 학급수  1학년 학생 수  2학년 학급수  2학년 학생 수  \
# 0        서울특별시 강남구            국립국악고등학교        5       150        5       149
# 1        서울특별시 성북구     서울대학교사범대학부설고등학교        8       239        8       228
# 2        서울특별시 금천구          국립전통예술고등학교        6       182        6       174
# 3        서울특별시 송파구              가락고등학교       11       282       11       262
# 4        서울특별시 강동구              강동고등학교        8       210        8       183
# ...            ...                 ...      ...       ...      ...       ...
# 2393   제주특별자치도 제주시              제주고등학교       11       279       11       279
# 2394  제주특별자치도 서귀포시         서귀포산업과학고등학교        8       151        8       141
# 2395  제주특별자치도 서귀포시              성산고등학교        4        76        5        91
# 2396   제주특별자치도 제주시           제주외국어고등학교        4        99        4        95
# 2397   제주특별자치도 제주시  제주제일고등학교부설방송통신고등학교        5       116        5        98
#
#       3학년 학급수  3학년 학생 수
# ...

# %% [markdown]
# # 3.전국의 고등학교에 대해 각 학교의 총 학생수(1,2,3학년 학생수의 합)을 구해 마지막 열에 삽입하는 프로그램을 작성하시오.

# %%
df.loc[:,['1학년 학생 수','2학년 학생 수','3학년 학생 수']]
# Out:
#       1학년 학생 수  2학년 학생 수  3학년 학생 수
# 0          150       149       143
# 1          239       228       270
# 2          182       174       169
# 3          282       262       288
# 4          210       183       221
# ...        ...       ...       ...
# 2393       279       279       305
# 2394       151       141       135
# 2395        76        91       103
# 2396        99        95        92
# 2397       116        98       126
#
# [2398 rows x 3 columns]

# %%
df['총 학생 수'] = df1.sum(axis=1).astype(int)
df
# Out:
#                 지역                 학교명  1학년 학급수  1학년 학생 수  2학년 학급수  2학년 학생 수  \
# 0        서울특별시 강남구            국립국악고등학교        5       150        5       149
# 1        서울특별시 성북구     서울대학교사범대학부설고등학교        8       239        8       228
# 2        서울특별시 금천구          국립전통예술고등학교        6       182        6       174
# 3        서울특별시 송파구              가락고등학교       11       282       11       262
# 4        서울특별시 강동구              강동고등학교        8       210        8       183
# ...            ...                 ...      ...       ...      ...       ...
# 2393   제주특별자치도 제주시              제주고등학교       11       279       11       279
# 2394  제주특별자치도 서귀포시         서귀포산업과학고등학교        8       151        8       141
# 2395  제주특별자치도 서귀포시              성산고등학교        4        76        5        91
# 2396   제주특별자치도 제주시           제주외국어고등학교        4        99        4        95
# 2397   제주특별자치도 제주시  제주제일고등학교부설방송통신고등학교        5       116        5        98
#
#       3학년 학급수  3학년 학생 수  총 학생 수
# ...

# %%
df.iloc[:,2:]
# Out:
#       1학년 학급수  1학년 학생 수  2학년 학급수  2학년 학생 수  3학년 학급수  3학년 학생 수  총 학생 수
# 0           5       150        5       149        5       143    1768
# 1           8       239        8       228        8       270    2948
# 2           6       182        6       174        6       169    2100
# 3          11       282       11       262       11       288    3328
# 4           8       210        8       183        8       221    2456
# ...       ...       ...      ...       ...      ...       ...     ...
# 2393       11       279       11       279       11       305    3452
# 2394        8       151        8       141        8       135    1708
# 2395        4        76        5        91        5       103    1080
# 2396        4        99        4        95        4        92    1144
# 2397        5       116        5        98        5       126    1360
#
# [2398 rows x 7 columns]

# %%
df2 = df.iloc[:,[3,5,7]]

df2.columns = ['1학년 총 학생 수','2학년 총 학생 수','3학년 총 학생 수']
df2 = df2.sum(axis=0)
df2
# Out:
# 1학년 총 학생 수    463400
# 2학년 총 학생 수    444714
# 3학년 총 학생 수    500698
# dtype: int64

# %%
print(df2)
df2.plot.bar(rot=0)
plt.xlabel = ['1학년','2학년','3학년']
plt.show()
# Out:
# 1학년 총 학생 수    463400
# 2학년 총 학생 수    444714
# 3학년 총 학생 수    500698
# dtype: int64

# %% [markdown]
# # 5. 4번의 DataFrame에 저장된 데이터를 '100세 이상'열을 기준으로 하여 내림차순으로 정렬한 다음 실행 결과와 같이 출력하는 프로그램을 작성하시오.

# %%
df = pd.read_csv('population_age_2020.csv',skiprows=[0],
                 names = ['지역','총 인구 수','0~9세','10~19세','20~29세','30~39세',
                          '40~49세','50~59세','60~69세','70~79세','80~89세','90~99세','100세 이상'])
df
# Out:
#       지역    총 인구 수     0~9세   10~19세   20~29세   30~39세   40~49세   50~59세  \
# 0     서울   9736962   658355   813563  1455903  1505729  1563968  1539385
# 1     부산   3410925   241624   281120   434692   431911   518321   580966
# 2     대구   2432883   186623   234528   321487   303397   391997   428622
# 3     인천   2954955   239941   281097   405835   417708   490716   515758
# 4     광주   1456121   125396   162728   207554   191432   244903   234048
# 5     대전   1473125   120476   151861   212143   199106   242381   243526
# 6     울산   1145710   103399   115623   147745   158271   190698   211255
# 7     세종    343788    47454    40574    36273    61442    65714    42907
# 8    경기도  13265377  1178548  1347854  1769080  1917785  2299179  2205106
# 9    강원도   1539521   108694   141975   179813   169694   227950   269666
# 10  충청북도   1598599   128290   153119   198910   198768   243982   273857
# 11  충청남도   2120995   179808   206578   243748   276553   329789   340568
# ...

# %%
df2 = df.loc[:,['지역','100세 이상','총 인구 수']]
df2
# Out:
#       지역  100세 이상    총 인구 수
# 0     서울     6380   9736962
# 1     부산     1807   3410925
# 2     대구      694   2432883
# 3     인천      908   2954955
# 4     광주      405   1456121
# 5     대전      339   1473125
# 6     울산      160   1145710
# 7     세종       55    343788
# 8    경기도     4010  13265377
# 9    강원도      803   1539521
# 10  충청북도      541   1598599
# 11  충청남도      885   2120995
# 12  전라북도      817   1815112
# 13  전라남도      822   1861894
# 14  경상북도      960   2658956
# 15  경상남도      739   3358828
# 16   제주도      266    670876

# %%
df2.sort_values(by=['100세 이상'],ascending=False)
# Out:
#       지역  100세 이상    총 인구 수
# 0     서울     6380   9736962
# 8    경기도     4010  13265377
# 1     부산     1807   3410925
# 14  경상북도      960   2658956
# 3     인천      908   2954955
# 11  충청남도      885   2120995
# 13  전라남도      822   1861894
# 12  전라북도      817   1815112
# 9    강원도      803   1539521
# 15  경상남도      739   3358828
# 2     대구      694   2432883
# 10  충청북도      541   1598599
# 4     광주      405   1456121
# 5     대전      339   1473125
# 16   제주도      266    670876
# 6     울산      160   1145710
# 7     세종       55    343788
